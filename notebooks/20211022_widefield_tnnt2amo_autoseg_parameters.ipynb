# %%
import sys
sys.path.append("../SpikeCounter")
import numpy as np
import skimage.io as skio
import scipy.ndimage as ndi
import scipy.signal as signal
import scipy.stats as stats
import skimage.morphology as morphology
import matplotlib.pyplot as plt
import skimage.transform as transform
from tifffile import imsave
import scipy.ndimage as ndimage
import matplotlib.colors as colors
import matplotlib.patches as patches
import os
from scipy import interpolate, optimize
import skimage.filters as filters
import pandas as pd
from datetime import datetime
import skimage.measure as measure
from scipy.fft import fft, fftfreq, rfft
plt.style.use("../bio_pubs_presentation.mplstyle")
# %matplotlib inline
import importlib

# %%
from spikecounter.analysis import traces, images
from spikecounter.ui import visualize
from spikecounter import utils
from sklearn.decomposition import PCA

# %%
def reload_libraries():
    importlib.reload(visualize)
    importlib.reload(images)
    importlib.reload(traces)

# %%
rootdir = "/n/holyscratch01/cohen_lab/bjia/20211022_widefield_tnnt2aMO_control/corrected"
expt_info = pd.read_csv(os.path.join(rootdir, "../analysis", "experiment_data.csv")).sort_values("start_time").reset_index()
start_times = [datetime.strptime(t,"%H:%M:%S") for t in list(expt_info["start_time"])]
offsets = [s - start_times[0] for s in start_times]
offsets = [o.seconds for o in offsets]
expt_info["offset"] = offsets
fs = 10.2
factor = 4

# %%
os.makedirs(os.path.join(rootdir, "denoised/analysis"),\
            exist_ok=True)
expt_info.to_csv(os.path.join(rootdir, "denoised/analysis/experiment_data.csv"), index=False)

# %%
filenames = np.flip(np.array(expt_info["file_name"]))

# %%
f_s = fs
block_size = 375
offset = 0.01
band_threshold = 0.55
band_bounds=(0.15,2.5)
opening_size=5
dilation_size = 3
corr_threshold = 0.85

# %%
plt.close("all")
img = skio.imread(os.path.join(rootdir, "%s.tif" % filenames[30]))

# %%
filenames[30]
# Out:
# '105741_p1_t90_p1_z1'

# %%
utils.display_zstack(img[400:600], pct_cutoffs=[0,100])
# Out:
# interactive(children=(IntSlider(value=99, description='z', max=199), Dropdown(description='c', options=('all',…

# %%
mean_img = img.mean(axis=0)
mean_trace = img.mean(axis=(1,2))
q = plt.imshow(mean_img)
plt.colorbar(q)

# %%
reload_libraries()

# %%
intensity_mask, abs_power, smoothed_band_power2, initial_guesses, corr_img

# %%
curr_labels, curr_coms = images.identify_hearts(\
                                            img, \
                                            opening_size=opening_size, dilation_size=dilation_size, \
                                            band_bounds=band_bounds, band_threshold=band_threshold, \
                                            f_s=fs, corr_threshold=corr_threshold, \
                                            block_size=block_size, offset=offset)

# %%
plt.imshow(curr_labels)

# %%
intensity_mask_manual = mean_img > filters.threshold_local(mean_img, block_size, offset=offset)
fig1, axes = plt.subplots(1,2, figsize=(8,4))
# axes[0].imshow(intensity_mask)
axes[1].imshow(intensity_mask_manual)

# %%
zeroed_image = img-mean_img
local_thresh = filters.threshold_local(mean_img, block_size=block_size, offset=offset)
# intensity_mask = mean_img > np.percentile(mean_img, intensity_threshold*100)
intensity_mask = mean_img > local_thresh

pixelwise_fft = fft(zeroed_image, axis=0)
N_samps = img.shape[0]
fft_freq = fftfreq(N_samps, 1/f_s)[:N_samps//2]
abs_power = np.abs(pixelwise_fft[:N_samps//2,:,:])**2
norm_abs_power = abs_power/np.sum(abs_power, axis=0)

# %%
cumsum = np.cumsum(norm_abs_power,axis=0)

# %%
median_power_idx = np.apply_along_axis(lambda x: np.argwhere(x>0.5).ravel()[0], 0, cumsum)

# %%
median_power = np.ma.masked_array(fft_freq[median_power_idx], mask=~intensity_mask)

# %%
q = plt.imshow(median_power)
plt.colorbar(q)

# %%
plt.imshow(np.ma.masked_array(np.mean(abs_power, axis=0), mask=~intensity_mask))

# %%
band_power = np.sum(norm_abs_power[(fft_freq>band_bounds[0]) & (fft_freq<band_bounds[1]),:,:], axis=0)
smoothed_band_power = filters.median(band_power, footprint=np.ones((5,5)))*intensity_mask.astype(int)
processed_band_power = morphology.binary_opening((smoothed_band_power > band_threshold), footprint=np.ones((3,3)))
plt.imshow(processed_band_power)
# Out:
# /tmp/ipykernel_87755/788372683.py:2: FutureWarning: `footprint` is a deprecated argument name for `median`. It will be removed in version 1.0. Please use `footprint` instead.
#   smoothed_band_power = filters.median(band_power, footprint=np.ones((5,5)))*intensity_mask.astype(int)
# /tmp/ipykernel_87755/788372683.py:3: FutureWarning: `footprint` is a deprecated argument name for `binary_opening`. It will be removed in version 1.0. Please use `footprint` instead.
#   processed_band_power = morphology.binary_opening((smoothed_band_power > band_threshold), footprint=np.ones((3,3)))

# %%
initial_guesses = measure.label(processed_band_power)

# %%
bboxes = [p["bbox"] for p in measure.regionprops(initial_guesses)]
new_mask = np.zeros_like(mean_img, dtype=bool)
#     new_mask_labels = np.deepcopy(initial_guesses)
n_rois = np.max(initial_guesses)
corr_img = np.zeros((n_rois, mean_img.shape[0], mean_img.shape[1]), dtype=float)

# %%
bbox_offset=5
for i in range(1, n_rois+1):
    bbox = bboxes[i-1]
    r1 = max(bbox[0]-bbox_offset, 0)
    c1 = max(bbox[1]-bbox_offset, 0)
    r2 = min(bbox[2]+bbox_offset, initial_guesses.shape[0])
    c2 = min(bbox[3]+bbox_offset, initial_guesses.shape[1])
#         print(r1,r2,c1,c2)
    roi_mask = np.zeros_like(initial_guesses, dtype=bool)
    roi_mask[r1:r2, c1:c2] = 1    
    initial_trace = images.extract_mask_trace(zeroed_image, mask = roi_mask)
    roi_traces = zeroed_image[:,roi_mask]
#         print(roi_traces.shape)
    corrs = np.apply_along_axis(lambda x: stats.pearsonr(initial_trace, x)[0], 0, roi_traces)
    corrs = corrs.reshape((r2-r1, c2-c1))
    corr_img[i-1, r1:r2, c1:c2] = corrs

# %%
plt.imshow(corr_img.max(axis=0))

# %%
plt.imshow(corr_img.max(axis=0) > 0.6)

# %%
for i in np.arange(labels.max())+1:
    print(i, np.mean(smoothed_band_power[labels==i]))
# Out:
# 1 0.753135376619634
# 2 0.6806502958157856
# 3 0.47350992642448414
# 4 0.6940207829303442
# 5 0.7379837760313139
# 6 0.5702381642276811
# 7 0.5841424442225697
# 8 0.4663434885923864
# 9 0.5115455025131954
# 10 0.5496208147314483
# 11 0.7273187985082921
# 12 0.5894589216304644
# 13 0.6805860034636597
# 14 0.6500936215150989
# 15 0.6182655122195237
# 16 0.7322687614187573
# 17 0.47376755115031555
# 18 0.6601245839578945
# 19 0.685607899649221
# 20 0.6468291065831501
# 21 0.6684830334539291
# 22 0.6780824271295282
# 23 0.6630454731004765

# %%
visualize.display_roi_overlay(mean_img, labels)
# Out:
# (<Figure size 720x864 with 1 Axes>,
#  <AxesSubplot:>,
#  <matplotlib.image.AxesImage at 0x2b09e2443e80>,
#  <matplotlib.image.AxesImage at 0x2b09e23a9af0>)

# %%
f_s = fs
block_size = 375
offset = 0.01
band_threshold = 0.52
band_bounds=(0.15,2.5)
opening_size=5
dilation_size = 3
corr_threshold = 0.8

# %%
reload_libraries()

# %%
expt_info = pd.read_csv(expt_info_path).sort_values("start_time").reset_index()

# %%
expt_info_path = "/n/holyscratch01/cohen_lab/bjia/20210724_gcamp_widefield/corrected/analysis/experiment_data.csv"
data_folder = "/n/holyscratch01/cohen_lab/bjia/20210724_gcamp_widefield/corrected/"
expt_info = pd.read_csv(expt_info_path).sort_values("start_time").reset_index()

filenames = expt_info["file_name"].tolist()
print(len(filenames))

# if end_idx == 0:
#     filenames = filenames[args.start_idx:len(filenames)]
# else:
#     filenames = filenames[args.start_idx:args.end_idx+1]
filenames = filenames[-30:-29]

pathnames = [os.path.join(data_folder, "%s.tif" % f) for f in filenames]
print(pathnames)
vid, exclude_from_write = images.segment_widefield_series(pathnames, \
                                      f_s=f_s, band_bounds=band_bounds, opening_size=opening_size,\
                                     dilation_size=dilation_size, band_threshold=band_threshold,\
                                      block_size=block_size, offset=offset, corr_threshold=corr_threshold)
os.makedirs(os.path.join(data_folder, "analysis"), exist_ok=True)
skio.imsave(os.path.join(data_folder, "analysis", "unlinked_segmentation_video.tif"), vid)
linked_vid = images.link_stack(vid)
# Out:
# 120
# ['/n/holyscratch01/cohen_lab/bjia/20210724_gcamp_widefield/corrected/102356_p1_t91_p1_z1.tif']
# /tmp/ipykernel_38742/2750398325.py:21: UserWarning: /n/holyscratch01/cohen_lab/bjia/20210724_gcamp_widefield/corrected/analysis/unlinked_segmentation_video.tif is a low contrast image
#   skio.imsave(os.path.join(data_folder, "analysis", "unlinked_segmentation_video.tif"), vid)

# %% [markdown]
# ### Manually link videos

# %%
autoseg_video = skio.imread(os.path.join(rootdir, "denoised/analysis", "segmentation_video.tif"))

# %%
utils.display_zstack(autoseg_video, pct_cutoffs=[0,100])
# Out:
# interactive(children=(IntSlider(value=63, description='z', max=127), Dropdown(description='c', options=('all',…

# %%
vid = skio.imread(os.path.join(rootdir, "denoised/analysis", \
                                          "unlinked_segmentation_video.tif"))

# %%
utils.display_zstack(vid, pct_cutoffs=[0,100])
# Out:
# interactive(children=(IntSlider(value=44, description='z', max=89), Dropdown(description='c', options=('all', …

# %%
linked_vid = link_stack(vid)

filtered_vid = filter_by_appearances(linked_vid, vid, threshold = 0.03)
filled_vid = fill_missing(filtered_vid)
forward_time_vid = np.flip(filled_vid, axis=0)

# %%
utils.display_zstack(forward_time_vid, pct_cutoffs=[0,100])
# Out:
# interactive(children=(IntSlider(value=44, description='z', max=89), Dropdown(description='c', options=('all', …

# %%
skio.imsave(os.path.join(rootdir, "denoised/analysis", "segmentation_video.tif"), forward_time_vid)
# Out:
# /tmp/ipykernel_100453/3341719579.py:1: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/segmentation_video.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "segmentation_video.tif"), forward_time_vid)

# %%
for i in range(forward_time_vid.shape[0]):
    f = expt_info["file_name"].iloc[i]
    skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# Out:
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/091621_p1_t1_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/091820_p1_t2_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/092019_p1_t3_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/092218_p1_t4_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/092417_p1_t5_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/092616_p1_t6_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/092816_p1_t7_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/093015_p1_t8_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/093214_p1_t9_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/093413_p1_t10_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/093612_p1_t11_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/093811_p1_t12_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/094010_p1_t13_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/094209_p1_t14_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/094409_p1_t15_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/094608_p1_t16_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/094807_p1_t17_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/095006_p1_t18_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/095205_p1_t19_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/095404_p1_t20_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/095603_p1_t21_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/095802_p1_t22_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/100001_p1_t23_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/100201_p1_t24_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/100400_p1_t25_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/100559_p1_t26_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/100758_p1_t27_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/100957_p1_t28_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/101156_p1_t29_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/101355_p1_t30_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/101808_p1_t1_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/102007_p1_t2_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/102207_p1_t3_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/102406_p1_t4_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/102605_p1_t5_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/102804_p1_t6_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/103003_p1_t7_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/103202_p1_t8_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/103402_p1_t9_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/103601_p1_t10_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/103800_p1_t11_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/103959_p1_t12_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/104158_p1_t13_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/104358_p1_t14_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/104557_p1_t15_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/104756_p1_t16_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/104955_p1_t17_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/105154_p1_t18_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/105353_p1_t19_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/105553_p1_t20_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/105752_p1_t21_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/105951_p1_t22_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/110150_p1_t23_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/110349_p1_t24_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/110548_p1_t25_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/110748_p1_t26_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/110947_p1_t27_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/111146_p1_t28_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/111345_p1_t29_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/111544_p1_t30_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/111822_p1_t1_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/112021_p1_t2_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/112221_p1_t3_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/112420_p1_t4_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/112619_p1_t5_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/112818_p1_t6_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/113017_p1_t7_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/113216_p1_t8_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/113416_p1_t9_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/113615_p1_t10_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/113814_p1_t11_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/114013_p1_t12_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/114213_p1_t13_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/114412_p1_t14_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/114611_p1_t15_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/114810_p1_t16_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/115010_p1_t17_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/115209_p1_t18_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/115408_p1_t19_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/115607_p1_t20_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/115806_p1_t21_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/120006_p1_t22_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/120205_p1_t23_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/120404_p1_t24_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/120603_p1_t25_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/120802_p1_t26_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/121001_p1_t27_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/121201_p1_t28_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/121400_p1_t29_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
# /tmp/ipykernel_100453/1699935631.py:3: UserWarning: /n/holyscratch01/cohen_lab/bjia/20220216_endogenous_activity_nkxzsy/denoised/analysis/automasks/121559_p1_t30_p1_z1_mask.tif is a low contrast image
#   skio.imsave(os.path.join(rootdir, "denoised/analysis", "automasks/%s_mask.tif" % f), forward_time_vid[i,:,:])
